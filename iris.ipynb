# %% [markdown]
# <a href="https://colab.research.google.com/github/PrajwalUnaik/100daysofcode__python/blob/main/iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data loading and overview

# %%
from sklearn.datasets import load_iris
import pandas as pd
import matplotlib.pyplot as plt

data = load_iris(as_frame=True)
df = data.frame

df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %% [markdown]
# Simple Random Sampling

# %%
sampled_df = df.sample(n = 30, random_state=42)

# %%
df['sepal length (cm)'].hist(figsize=(8, 6), edgecolor='black')
plt.title('Histogram of Sepal Length (Original Data)')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Frequency')
plt.show()

# %%
df['sepal length (cm)'].hist(figsize=(8, 6), edgecolor='black')
plt.title('Histogram of Sepal Length (Sampled Data)')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Frequency')
plt.show()

# %%
df['sepal length (cm)'].hist(figsize=(8, 6), edgecolor='black')
df['sepal length (cm)'].hist(figsize=(8, 6),bins = 20 , edgecolor='black')
plt.title('Histogram of Sepal Length (Original and Sampled Data)')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Frequency')
plt.show()

# %%
num_repetitions = 100

sample_size = 30

sample_means = []

for _ in range(num_repetitions):
    sample = df['sepal length (cm)'].sample(n=sample_size, random_state=np.random.randint(1, 10000))
    sample_means.append(sample.mean())

plt.hist(sample_means, bins=20, edgecolor='black')
plt.title('Distribution of Sample Means (Sepal Length)')
plt.xlabel('Sample Mean')
plt.ylabel('Frequency')
plt.show()

print(f"Mean of sample means: {np.mean(sample_means)}")
print(f"Standard deviation of sample means: {np.std(sample_means)}")
# Out:
# Mean of sample means: 5.841266666666667
# Standard deviation of sample means: 0.11288812554422575
